# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
nyCity_df = pd.read_csv("201908-citibike-tripdata.csv")
nyCity_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
# 1b. Sort descending
nyCity_sorted_df = nyCity_df.sort_values(by='tripduration', ascending=False)
nyCity_sorted_df.head()
# Out:
#         tripduration                 starttime                  stoptime  \
# 189706       3812666  2019-08-03 11:31:37.2370  2019-09-16 14:36:03.3340
# 385277       3341929  2019-08-05 19:53:13.6550  2019-09-13 12:12:02.9690
# 397609       2704549  2019-08-06 02:43:44.4590  2019-09-06 09:59:33.9580
# 667440       2584590  2019-08-09 17:47:28.6360  2019-09-08 15:43:58.9520
# 679106       2578232  2019-08-09 19:34:51.7360  2019-09-08 15:45:23.9810
#
#         start station id                   start station name  \
# 189706             453.0                      W 22 St & 8 Ave
# 385277            3349.0     Grand Army Plaza & Plaza St West
# 397609            3511.0  Adam Clayton Powell Blvd & W 115 St
# 667440             501.0                  FDR Drive & E 35 St
# 679106             528.0                      2 Ave & E 31 St
#
#         start station latitude  start station longitude  end station id  \
# 189706               40.744751               -73.999154          3245.0
# ...

# %%
# 2. Check the datatypes of your columns. 
nyCity_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
nyCity_df['tripduration'] = pd.to_datetime(nyCity_df['tripduration'], unit='s')

# %%
nyCity_sorted_df = nyCity_df.sort_values(by='tripduration', ascending=False)
nyCity_sorted_df.head()
# Out:
#               tripduration                 starttime  \
# 189706 1970-02-14 03:04:26  2019-08-03 11:31:37.2370
# 385277 1970-02-08 16:18:49  2019-08-05 19:53:13.6550
# 397609 1970-02-01 07:15:49  2019-08-06 02:43:44.4590
# 667440 1970-01-30 21:56:30  2019-08-09 17:47:28.6360
# 679106 1970-01-30 20:10:32  2019-08-09 19:34:51.7360
#
#                         stoptime  start station id  \
# 189706  2019-09-16 14:36:03.3340             453.0
# 385277  2019-09-13 12:12:02.9690            3349.0
# 397609  2019-09-06 09:59:33.9580            3511.0
# 667440  2019-09-08 15:43:58.9520             501.0
# 679106  2019-09-08 15:45:23.9810             528.0
#
#                          start station name  start station latitude  \
# 189706                      W 22 St & 8 Ave               40.744751
# 385277     Grand Army Plaza & Plaza St West               40.672968
# 397609  Adam Clayton Powell Blvd & W 115 St               40.802535
# ...

# %%
# 4. Check the datatypes of your columns. 
nyCity_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
output_data_file = "../bikesharing/bikedata.csv"
nyCity_df.to_csv(output_data_file)
